# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# use in 2_SoilGrid_Average0-30cm.ipynb
import rasterio
import numpy as np
import os

# use in 3_ZonalStats_VillageBuffer_GeoChars.ipynb
from rasterstats import zonal_stats

# config
from pathlib import Path

# Base project path (edit once)
BASE     = Path("/Users/kc/Desktop/CERDIProject/TermiteMound/Script/RawData")


# Common paths
PROV_PATH      = BASE / "ShapeFile" / "shp_census_2008" / "census_2008_provinces" / "province_2008.shp"
CATCH_PATH     = BASE / "ShapeFile" / "ChreyBak_catchment" / "CB_District.kml"
WATER_PATH     = BASE / "ShapeFile" / "hotosm_khm_waterways_lines_shp/hotosm_khm_waterways_lines_shp.shp"

SOIL_PATH      = BASE / "ShapeFile" / "SoilGrid_Cambodia"
GEO_PATH       = BASE / "ShapeFile" / "GeoEarthenv"
CLIMATE_PATH   = BASE / "ShapeFile" / "WorldClimate"

TM_Vill_PATH   = BASE / "TM_Village.csv"
VILL_IN_PATH   = BASE / "TM_Village_with_geo_climate_1km.csv"
VILL_OUT_PATH  = BASE / "TM_Village_with_geo_climate_1km_waterdist.csv"

# Common column names
LON_COL = "xcoor"
LAT_COL = "ycoor"
ID_COL  = "vill_code"
